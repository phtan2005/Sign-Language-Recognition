# %%
total_weight = 4 + 3 + 2  # = 9 phần / 9 parts
combo_shares   = int(delta_needed × 4/9 / 2.0) + 1  # = 26960
combo_comments = int(delta_needed × 3/9 / 1.5) + 1  # = 26960
combo_likes    = int(delta_needed × 2/9 / 1.0) + 1  # = 26960
# Kết quả / Result: +26960 shares · +26960 comments · +26960 likes
# ER mới / New ER: 13.30%  ≥  P80
